# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data2.csv")

# %%
df
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      01-01-2022     S001      P0001  Electronics  North              195
# 1      01-01-2022     S001      P0002     Clothing  North              117
# 2      01-01-2022     S001      P0003     Clothing  North              247
# 3      01-01-2022     S001      P0004  Electronics  North              139
# 4      01-01-2022     S001      P0005    Groceries  North              152
# ...           ...      ...        ...          ...    ...              ...
# 75995  30-01-2024     S005      P0016         Toys  North              233
# 75996  30-01-2024     S005      P0017         Toys  North              137
# 75997  30-01-2024     S005      P0018     Clothing  North              197
# 75998  30-01-2024     S005      P0019    Furniture  North              125
# 75999  30-01-2024     S005      P0020         Toys  North              126
#
# ...

# %%
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  01-01-2022     S001      P0001  Electronics  North              195
# 1  01-01-2022     S001      P0002     Clothing  North              117
# 2  01-01-2022     S001      P0003     Clothing  North              247
# 3  01-01-2022     S001      P0004  Electronics  North              139
# 4  01-01-2022     S001      P0005    Groceries  North              152
#
#    Units_Sold  Units_Ordered  Price  Discount Weather_Condition  Promotion  \
# 0         102          252.0  72.72         5             Snowy          0
# 1         117          249.0  80.16        15             Snowy          1
# 2         114          612.0  62.94        10             Snowy          1
# 3          45            NaN  87.63        10             Snowy          0
# 4          65          271.0  54.41         0             Snowy          0
#
#    Competitor_Pricing Seasonality  Epidemic  Demand
# ...

# %%
df.tail()
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 75995  30-01-2024     S005      P0016       Toys  North              233
# 75996  30-01-2024     S005      P0017       Toys  North              137
# 75997  30-01-2024     S005      P0018   Clothing  North              197
# 75998  30-01-2024     S005      P0019  Furniture  North              125
# 75999  30-01-2024     S005      P0020       Toys  North              126
#
#        Units_Sold  Units_Ordered   Price  Discount Weather_Condition  \
# 75995          63            NaN   29.80         5             Snowy
# 75996         115          141.0   42.92         5             Snowy
# 75997          44            0.0   17.81        10             Snowy
# 75998          58            0.0  151.72         0             Snowy
# 75999          63           59.0   25.78        10             Snowy
#
#        Promotion  Competitor_Pricing Seasonality  Epidemic  Demand
# ...

# %%
df.head(10)
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  01-01-2022     S001      P0001  Electronics  North              195
# 1  01-01-2022     S001      P0002     Clothing  North              117
# 2  01-01-2022     S001      P0003     Clothing  North              247
# 3  01-01-2022     S001      P0004  Electronics  North              139
# 4  01-01-2022     S001      P0005    Groceries  North              152
# 5  01-01-2022     S001      P0006         Toys  North              209
# 6  01-01-2022     S001      P0007    Groceries  North              118
# 7  01-01-2022     S001      P0008  Electronics  North              244
# 8  01-01-2022     S001      P0009     Clothing  North              115
# 9  01-01-2022     S001      P0010    Furniture  North              192
#
#    Units_Sold  Units_Ordered   Price  Discount Weather_Condition  Promotion  \
# 0         102          252.0   72.72         5             Snowy          0
# ...

# %%
df.tail(10)
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 75990  30-01-2024     S005      P0011  Electronics  North              269
# 75991  30-01-2024     S005      P0012    Furniture  North              375
# 75992  30-01-2024     S005      P0013    Groceries  North              792
# 75993  30-01-2024     S005      P0014    Furniture  North              161
# 75994  30-01-2024     S005      P0015    Groceries  North              520
# 75995  30-01-2024     S005      P0016         Toys  North              233
# 75996  30-01-2024     S005      P0017         Toys  North              137
# 75997  30-01-2024     S005      P0018     Clothing  North              197
# 75998  30-01-2024     S005      P0019    Furniture  North              125
# 75999  30-01-2024     S005      P0020         Toys  North              126
#
#        Units_Sold  Units_Ordered   Price  Discount Weather_Condition  \
# 75990          49            0.0   74.76         0             Snowy
# ...

# %%
df.shape
# Out:
# (76000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76000 entries, 0 to 75999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                76000 non-null  object
#  1   Store ID            76000 non-null  object
#  2   Product ID          76000 non-null  object
#  3   Category            76000 non-null  object
#  4   Region              76000 non-null  object
#  5   Inventory Level     76000 non-null  int64
#  6   Units_Sold          76000 non-null  int64
#  7   Units_Ordered       75990 non-null  float64
#  8   Price               76000 non-null  float64
#  9   Discount            76000 non-null  int64
#  10  Weather_Condition   76000 non-null  object
#  11  Promotion           76000 non-null  int64
#  12  Competitor_Pricing  76000 non-null  float64
#  13  Seasonality         76000 non-null  object
#  14  Epidemic            76000 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Inventory Level    Units_Sold  Units_Ordered         Price  \
# count     76000.000000  76000.000000   75990.000000  76000.000000
# mean        301.062842     88.827316      89.091091     67.726028
# std         226.510161     43.994525     162.410895     39.377899
# min           0.000000      0.000000       0.000000      4.740000
# 25%         136.000000     58.000000       0.000000     31.997500
# 50%         227.000000     84.000000       0.000000     64.500000
# 75%         408.000000    114.000000     121.000000     95.830000
# max        2267.000000    426.000000    1616.000000    228.030000
#
#            Discount     Promotion  Competitor_Pricing      Epidemic  \
# count  76000.000000  76000.000000        76000.000000  76000.000000
# mean       9.087039      0.328947           69.454029      0.200000
# std        7.475781      0.469834           40.943818      0.400003
# min        0.000000      0.000000            4.290000      0.000000
# ...

# %%
df.Discount
# Out:
# 0         5
# 1        15
# 2        10
# 3        10
# 4         0
#          ..
# 75995     5
# 75996     5
# 75997    10
# 75998     0
# 75999    10
# Name: Discount, Length: 76000, dtype: int64

# %%
df.Discount.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.boxplot(df.Price)
# Out:
# <Axes: ylabel='Price'>

# %%
df = df[df.Price<=191]
df.shape
# Out:
# (75925, 16)

# %%
df.Price.hist()
# Out:
# <Axes: >

# %%
sns.boxplot(df.Price)
# Out:
# <Axes: ylabel='Price'>

# %%
df = df[['Units_Ordered','Price','Discount','Promotion','Epidemic','Demand']]

# %%
df
# Out:
#        Units_Ordered   Price  Discount  Promotion  Epidemic  Demand
# 0              252.0   72.72         5          0         0     115
# 1              249.0   80.16        15          1         0     229
# 2              612.0   62.94        10          1         0     157
# 3                NaN   87.63        10          0         0      52
# 4              271.0   54.41         0          0         0      59
# ...              ...     ...       ...        ...       ...     ...
# 75995            NaN   29.80         5          0         0      64
# 75996          141.0   42.92         5          0         0     137
# 75997            0.0   17.81        10          0         0      68
# 75998            0.0  151.72         0          0         0      84
# 75999           59.0   25.78        10          0         0      73
#
# [75925 rows x 6 columns]

# %%
df.isna()
# Out:
#        Units_Ordered  Price  Discount  Promotion  Epidemic  Demand
# 0              False  False     False      False     False   False
# 1              False  False     False      False     False   False
# 2              False  False     False      False     False   False
# 3               True  False     False      False     False   False
# 4              False  False     False      False     False   False
# ...              ...    ...       ...        ...       ...     ...
# 75995           True  False     False      False     False   False
# 75996          False  False     False      False     False   False
# 75997          False  False     False      False     False   False
# 75998          False  False     False      False     False   False
# 75999          False  False     False      False     False   False
#
# [75925 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Units_Ordered    10
# Price             0
# Discount          0
# Promotion         0
# Epidemic          0
# Demand            0
# dtype: int64

# %%
df.head(10)
# Out:
#    Units_Ordered   Price  Discount  Promotion  Epidemic  Demand
# 0          252.0   72.72         5          0         0     115
# 1          249.0   80.16        15          1         0     229
# 2          612.0   62.94        10          1         0     157
# 3            NaN   87.63        10          0         0      52
# 4          271.0   54.41         0          0         0      59
# 5            0.0   35.53         0          0         0      55
# 6          335.0   23.27         5          0         0      94
# 7            0.0   37.79         5          0         0      61
# 8          139.0   94.20         5          0         0     129
# 9          300.0  113.35        10          0         0      69

# %%
df = df.fillna(df.median())

# %%
df.head(10)
# Out:
#    Units_Ordered   Price  Discount  Promotion  Epidemic  Demand
# 0          252.0   72.72         5          0         0     115
# 1          249.0   80.16        15          1         0     229
# 2          612.0   62.94        10          1         0     157
# 3            0.0   87.63        10          0         0      52
# 4          271.0   54.41         0          0         0      59
# 5            0.0   35.53         0          0         0      55
# 6          335.0   23.27         5          0         0      94
# 7            0.0   37.79         5          0         0      61
# 8          139.0   94.20         5          0         0     129
# 9          300.0  113.35        10          0         0      69

# %%
df.isna().sum()
# Out:
# Units_Ordered    0
# Price            0
# Discount         0
# Promotion        0
# Epidemic         0
# Demand           0
# dtype: int64
